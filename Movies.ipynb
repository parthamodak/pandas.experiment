# %%
import pandas as pd
movies_data = pd.read_csv('movies.csv')
X = movies_data.drop(columns=['genre'])
y = movies_data['genre']
y
# Out:
# 0          Action
# 1          Action
# 2          Action
# 3          Sci-Fi
# 4          Sci-Fi
# 5          Sci-Fi
# 6           Drama
# 7           Drama
# 8           Drama
# 9          Comedy
# 10         Comedy
# 11         Comedy
# 12    Documentary
# 13    Documentary
# 14    Documentary
# 15          Drama
# 16          Drama
# 17          Drama
# Name: genre, dtype: object
